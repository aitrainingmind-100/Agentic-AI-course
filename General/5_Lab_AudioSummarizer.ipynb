# %%
from openai import OpenAI
import os
import tiktoken
# Set your API key
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

audio_path = "Arthur.mp3"  # <-- Put your audio file path here

#1 Transcribe
with open(audio_path, "rb") as f:
    transcript = client.audio.transcriptions.create(
        model="gpt-4o-mini-transcribe",
        file=f
    ).text

print("Transcript Preview:\n")
print(transcript[:800])

# ️Summarize
prompt = f"""
Summarize the following transcript into:
- Bullet summary
- Key insights
- Action items
- Decisions made
- Open questions

Transcript:
{transcript}
"""

summary = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": prompt}],
    temperature=0.2
)

print("\n\nSUMMARY:\n")
print(summary.choices[0].message.content)
# Out:
# Transcript Preview:
#
# The story of Arthur the rat. Once upon a time there was a young rat who couldn't make up his mind. Whenever the other rats asked him if he would like to come out hunting with them, he would answer in a hoarse voice, I don't know. And when they said, would you rather stay inside, he would say yes or no, either. He'd always shake making a choice. One fine day his Aunt Josephine said to him, Now look here, no one will ever care for you if you carry on like this. You have no more mind of your own and a greasy old blade of grass. The young rat coughed and looked quiet as usual, but said nothing. Don't you think so? said his aunt, stamping her foot, for she couldn't bear to see the young rat so cold-blooded. I don't know, was all he ever answered. And then he walked off to think for an hour or m
#
#
# SUMMARY:
#
# ### Bullet Summary
# - Arthur the rat struggles with indecision and is unable to make choices.
# - His Aunt Josephine expresses concern about his lack of decisiveness.
# - The rats' home becomes unsafe due to structural damage.
# - The leader rat organizes a search for a new home.
# - Arthur hesitates to join the others, preferring to stay in his familiar but unsafe environment.
# - Ultimately, the building collapses, and Arthur is found dead, illustrating the consequences of his indecision.
#
# ### Key Insights
# - Indecision can lead to negative outcomes and missed opportunities.
# - External pressures (like family concern) can highlight personal shortcomings.
# - Safety and comfort can sometimes trap individuals in harmful situations.
# - The importance of taking action rather than remaining passive in the face of danger.
#
# ### Action Items
# - Encourage individuals to make decisions promptly, especially in critical situations.
# - Foster an environment where seeking help for indecision is normalized.
# - Create discussions around the importance of weighing risks and benefits in decision-making.
#
# ### Decisions Made
# - The leader rat decided to evacuate the unsafe barn and search for a new home.
# - The group collectively chose to leave the barn despite Arthur's indecision.
#
# ### Open Questions
# - What could have motivated Arthur to make a decision sooner?
# - How can the community support individuals struggling with indecision?
# - What lessons can be learned from Arthur's fate to prevent similar situations in the future?
