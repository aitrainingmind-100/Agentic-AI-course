# %%
import tiktoken

encoding = tiktoken.get_encoding("cl100k_base")

text = "Can you tell me the weather for Minnesota?"

tokens = encoding.encode(text)

print("Tokens:", tokens)
print("Token count:", len(tokens))

decoded = encoding.decode(tokens)
print("Decoded back:", decoded)
# Out:
# Tokens: [6854, 499, 3371, 757, 279, 9282, 369, 19461, 30]
# Token count: 9
# Decoded back: Can you tell me the weather for Minnesota?
