# %% [markdown]
# Load Environment

# %%
from dotenv import load_dotenv

load_dotenv(override=True)

import os

# %%
import requests

OLLAMA_URL = "http://localhost:11434/api/generate"

print(" Local Llama3 Chat")
print("Type 'exit' to quit\n")

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Goodbye ")
        break

    payload = {
        "model": "llama3",
        "prompt": user_input,
        "stream": False
    }

    response = requests.post(OLLAMA_URL, json=payload)
    response.raise_for_status()

    answer = response.json()["response"]
    print("Llama3:", answer, "\n")
# Out:
#  Local Llama3 Chat
# Type 'exit' to quit
#
# Llama3: I'm just a language model, I don't have feelings or emotions like humans do. I exist solely to assist and communicate with users like you! I'm functioning properly and ready to help with any questions or topics you'd like to discuss. How can I assist you today?
#
# Llama3: Minnesota! The North Star State has a rich and diverse history spanning thousands of years. Here's an overview:
#
# **Indigenous Peoples (10,000 BCE - 1800s)**
#
# For thousands of years, various Native American tribes inhabited Minnesota. The Ojibwe (Chippewa), Dakota (Sioux), and Ho-Chunk (Winnebago) were some of the most prominent groups. They lived along the rivers, lakes, and forests, relying on hunting, gathering, and fishing for survival.
#
# **French Exploration and Trade (1600s - 1800s)**
#
# In the early 17th century, French explorers, including Pierre-Escande de La Salle and Jacques Marquette, arrived in Minnesota. They were followed by Jesuit missionaries who established missions among the Native American tribes. The French traded with the natives, introducing European goods like guns and metal tools.
#
# **American Acquisition (1803 - 1850s)**
#
# In 1803, the United States acquired the Louisiana Territory from France, which included present-day Minnesota. The region was part of the Northwest Territory, which was organized into the Michigan Territory in 1837. In 1849, the Iowa Territory was created, and Minnesota became a part of it.
#
# **Minnesota Territory (1849 - 1858)**
#
# In 1849, the United States Congress created the Minnesota Territory, with its capital in St. Peter. The territory grew rapidly, driven by the fur trade, mining, and agriculture. The first territorial governor was Alexander Ramsey, who played a key role in shaping the state's early development.
#
# **Statehood (1858)**
#
# On May 11, 1858, Minnesota became the 32nd state to join the United States. The state constitution was drafted in St. Paul, which would become the capital city. The state's early economy was based on agriculture, mining, and lumbering, with the railroad industry playing a significant role in its growth.
#
# **Civil War and Reconstruction (1861 - 1870s)**
#
# During the American Civil War, Minnesota contributed troops to the Union army, with over 34,000 soldiers serving. The state's economy suffered during the war, but it rebounded after Reconstruction.
#
# **Immigration and Population Growth (1880s - 1920s)**
#
# Massive immigration from Europe, particularly Norway, Sweden, and Germany, transformed Minnesota's demographics. The state's population grew rapidly, driven by agricultural expansion, mining, and industrialization.
#
# **Great Depression and World War II (1930s - 1940s)**
#
# Minnesota faced significant economic challenges during the Great Depression, with unemployment rates soaring. However, the state's agricultural industry helped it recover. During World War II, Minnesota played a crucial role in war production, contributing to the war effort through industries like aircraft manufacturing.
#
# **Post-War Growth and Social Change (1950s - 1980s)**
#
# Following World War II, Minnesota experienced rapid economic growth, driven by the expansion of industries like healthcare, technology, and finance. The civil rights movement also gained momentum in the state, with protests and activism for racial equality and women's rights.
#
# **Modern Era (1990s - present)**
#
# In recent decades, Minnesota has continued to diversify its economy, with a focus on biotechnology, clean energy, and tourism. The state has also seen significant population growth, driven by urbanization and the influx of new residents from other parts of the United States and abroad.
#
# This is just a brief overview of Minnesota's rich history. From its indigenous peoples to its modern-day innovations, the North Star State has a story worth telling!
#
# Llama3: I'm just an AI, I don't have have real-time access to current weather conditions. However, I can suggest some ways for you to find out the current weather in Minneapolis:
#
# 1. Check online weather websites: You can check websites like AccuWeather, Weather.com, or the National Weather Service (NWS) website for up-to-date weather information.
# 2. Use a weather app: Download a weather app on your smartphone, such as Dark Sky or The Weather Channel app, to get current weather conditions and forecasts.
# 3. Tune into local news: Watch local news stations or check their websites for the latest weather updates.
#
# Please note that the current weather in Minneapolis may change rapidly, so it's always best to check multiple sources for the most accurate information.
#
# Goodbye
