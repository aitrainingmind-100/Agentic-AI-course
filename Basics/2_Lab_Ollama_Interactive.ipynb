# %% [markdown]
# Load Environment

# %%
from dotenv import load_dotenv

load_dotenv(override=True)

import os

# %%
import requests

OLLAMA_URL = "http://localhost:11434/api/generate"

print(" Local Llama3 Chat")
print("Type 'exit' to quit\n")

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Goodbye ")
        break

    payload = {
        "model": "llama3",
        "prompt": user_input,
        "stream": False
    }

    response = requests.post(OLLAMA_URL, json=payload)
    response.raise_for_status()

    answer = response.json()["response"]
    print("Llama3:", answer, "\n")
# Out:
#  Local Llama3 Chat
# Type 'exit' to quit
#
# Llama3: Hello! It's nice to meet you. Is there something I can help you with, or would you like to chat?
#
# Llama3: I'm just a language model, I don't have feelings or emotions like humans do. However, I am functioning properly and ready to assist with any questions or tasks you may have! How can I help you today?
#
# Goodbye
