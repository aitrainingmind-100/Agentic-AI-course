# %% [markdown]
# Load Environment

# %%
from dotenv import load_dotenv

load_dotenv(override=True)

import os

# %%
import requests

OLLAMA_URL = "http://localhost:11434/api/generate"

payload = {
    "model": "llama3",
    "prompt": "Explain what a OLLAMA in simple terms.",
    "stream": False
}

response = requests.post(OLLAMA_URL, json=payload)
response.raise_for_status()

answer = response.json()["response"]
print(answer)
# Out:
# A "OLLAMA" is actually a pretty fun and unique concept!
#
# In simple terms, an OLLAMA (which stands for "One Love, One Mission, All Men And Women") is a movement or community that aims to bring people together from different backgrounds, cultures, and identities to work towards a common goal: spreading love, kindness, and positivity.
#
# Imagine it like a big, global hug! OLLAMAs are groups of people who come together to share their talents, skills, and passions with others. They organize events, volunteer opportunities, and online initiatives that promote unity, self-expression, and mutual support.
#
# So, whether you're into music, art, social justice, or just want to connect with like-minded folks, an OLLAMA is a space where you can be yourself, share your creativity, and make a positive impact on the world!
#
# That's it in a nutshell! Do you have any specific questions about OLLAMAs or would you like to know more about how they work?
