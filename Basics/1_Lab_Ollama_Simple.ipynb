# %% [markdown]
# Load Environment

# %%
from dotenv import load_dotenv

load_dotenv(override=True)

import os

# %%
import requests

OLLAMA_URL = "http://localhost:11434/api/generate"

payload = {
    "model": "llama3",
    "prompt": "Explain what a OLLAMA in simple terms.",
    "stream": False
}

response = requests.post(OLLAMA_URL, json=payload)
response.raise_for_status()

answer = response.json()["response"]
print(answer)
# Out:
# A OLLAMA is a type of online community or platform that connects people who share similar interests, hobbies, or passions. The term "OLLA" stands for "Online Learning and Language Alliance," but don't worry if you're not familiar with those words - it's just a fancy name!
#
# In simple terms, an OLLAMA is like an online club where people can:
#
# * Share their knowledge and skills
# * Learn from others
# * Discuss topics they care about
# * Make new friends who share similar interests
#
# Think of it like a big virtual gathering place where you can meet others who love the same things as you. For example, if you're interested in photography, there might be an OLLAMA for photographers where you can share your photos, get feedback, and learn from others.
#
# The idea is to create a supportive community where people can grow together, without geographical boundaries. So, if you have a passion or interest, there's probably an OLLAMA out there waiting for you!
