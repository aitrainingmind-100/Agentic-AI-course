# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()
client = OpenAI()

SYSTEM = """
You are a fact-based assistant.

GUARDRAILS:
- If you are unsure, say: "I don't know."
- Do NOT fabricate facts.
- Do NOT invent sources.
- Be concise and factual.
"""

def main():
    print("Safe Fact Assistant (type 'exit' to quit)\n")

    messages = [{"role": "system", "content": SYSTEM}]

    while True:
        user = input("You: ").strip()
        if user.lower() == "exit":
            break

        messages.append({"role": "user", "content": user})

        response = client.chat.completions.create(
            model="gpt-5-mini",
            messages=messages
        )

        answer = response.choices[0].message.content
        messages.append({"role": "assistant", "content": answer})

        print("\nModel:", answer, "\n")

if __name__ == "__main__":
    main()
# Out:
# Safe Fact Assistant (type 'exit' to quit)
#
#
# Model: I don't know a single "exact" distance — the Moon's distance from Earth changes. The commonly cited numbers (center-to-center) are:
#
# - Mean (average) distance: about 384,400 km (238,855 miles).
# - Typical closest (perigee): about 363,300 km (225,623 miles).
# - Typical farthest (apogee): about 405,500 km (251,968 miles).
#
# If you want the exact current distance at a specific time, you can get it from NASA/JPL tools (for example the JPL HORIZONS system) or other real‑time astronomy services.
#
#
# Model: In short: Antarctica is colder because it’s a high, dry landmass isolated from warm ocean heat, while the Arctic is a relatively low, sea‑ice covered ocean surrounded by continents that supply heat. Main reasons:
#
# - Elevation: Antarctica is a continent with an average elevation ≈ 2,300 m (ice sheet up to ~4 km thick). Temperature falls with altitude, so the high Antarctic interior is much colder than sea level Arctic air.
# - Surface type and heat capacity: The Arctic is mostly ocean covered by seasonal sea ice. Water stores and transports heat and moderates temperature. Antarctica is thick ice over land, which cannot store and release as much heat.
# - Oceanic isolation: The Antarctic Circumpolar Current and the Southern Ocean limit north–south exchange of warm water, reducing heat delivered to the continent.
# - Atmospheric isolation and strong polar vortex: Strong circumpolar winds and a strong Southern Hemisphere polar vortex isolate Antarctic air, reducing heat transport from lower latitudes.
# - Dryness and greenhouse effect: Antarctic air is very dry (low water‑vapor), so there is less greenhouse warming; dry air also radiates heat away more efficiently.
# - Geographic configuration: The Arctic is an ocean surrounded by relatively warm landmasses and ocean currents (e.g., Atlantic inflow) that bring heat poleward; Antarctica is a landmass surrounded by ocean, the opposite geometry.
#
# These factors combine so the Antarctic interior reaches much lower temperatures than the Arctic; for example, the coldest measured surface temperature on Earth (~−89°C at Vostok) occurs in Antarctica.
