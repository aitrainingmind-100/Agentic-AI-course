# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()
client = OpenAI()

SYSTEM = """
You are a financial education assistant.

GUARDRAILS:
- Provide general educational information only.
- Do NOT give personalized investment advice.
- Include a short risk disclaimer in every answer.
- Never guarantee returns.
"""

def main():
    print("Financial Education Assistant (type 'exit' to quit)\n")

    while True:
        question = input("You: ").strip()
        if question.lower() == "exit":
            break

        response = client.chat.completions.create(
            model="gpt-5-mini",
            messages=[
                {"role": "system", "content": SYSTEM},
                {"role": "user", "content": question}
            ]
        )

        print("\nAdvisor:\n", response.choices[0].message.content, "\n")

if __name__ == "__main__":
    main()
# Out:
# Financial Education Assistant (type 'exit' to quit)
#
#
# Advisor:
#  I can’t tell you whether you should buy Tesla right now, and I’m not able to give personalized investment advice. I can, however, walk you through a practical framework to decide for yourself and list the key things to check before making a trade.
#
# Quick summary first
# - Whether Tesla is a good buy for you depends on your goals, time horizon, risk tolerance, portfolio allocation, and the price you can buy at.
# - You should review Tesla’s recent financials, growth prospects, valuation, risks (competition, execution, regulation, commodity costs, China exposure), and how a Tesla position fits your overall portfolio.
# - If you want a structured approach, use the checklist below and consider dollar-cost averaging rather than timing a single entry.
#
# Checklist to evaluate Tesla (or any single stock)
# 1. Define your objective
#    - Why do you want Tesla exposure? Growth, thematic (EV/energy/AI), speculation?
#    - Time horizon (years vs months). EV/auto and software transitions are multi-year stories.
#
# 2. Personal constraints
#    - How much of your portfolio are you willing to allocate to a single equity?
#    - Your risk tolerance and ability to tolerate volatility.
#
# 3. Company fundamentals
#    - Revenue and unit (vehicle) growth trends and guidance.
#    - Gross and operating margin trends; free cash flow.
#    - Balance sheet (cash, debt, liquidity).
#    - Segment performance (vehicles, energy storage, services/software/FSD).
#
# 4. Valuation metrics
#    - Current P/E (trailing and forward), PEG if growth is accelerating/declining.
#    - EV/Revenue, EV/EBITDA, FCF yield, and comparison to peers and other growth stocks.
#    - How does the current price compare to intrinsic-value estimates (e.g., simple DCF scenarios)? Run multiple scenarios (bull, base, bear).
#
# 5. Industry and competitive factors
#    - EV adoption curves, charging infrastructure, battery supply and costs.
#    - Competition from legacy automakers and new entrants.
#    - China exposure and regulatory/political risk.
#    - Potential upside from autonomy and energy businesses — but note execution uncertainty.
#
# 6. Catalysts and upcoming events
#    - Upcoming earnings, delivery numbers, product launches (new models, FSD updates).
#    - Regulatory changes, subsidies, or tariffs that could affect demand or margins.
#
# 7. Market/positioning factors
#    - Recent price action and liquidity; short interest and investor sentiment.
#    - How adding Tesla changes your portfolio concentration and risk.
#
# 8. Execution & risk management
#    - Decide position size as a percentage of your portfolio, not an absolute dollar you “must” buy.
#    - Consider dollar-cost averaging if you’re uncertain about timing.
#    - Set rules for trimming or selling (e.g., rebalancing triggers, maximum drawdown you’ll tolerate).
#    - Avoid excessive leverage unless you fully understand margin risks.
#
# Due diligence sources
# - Tesla’s latest 10-K/10-Q and earnings transcripts (SEC EDGAR, investor relations).
# - Independent analyst reports, Morningstar, Bloomberg, Yahoo Finance, Seeking Alpha.
# - Coverage of macro conditions (interest rates, commodities like lithium/nickel) and China news.
#
# Common red flags to watch for
# - Repeated missed guidance or deteriorating margins.
# - Rising leverage or worsening cash flow while growth stalls.
# - Regulatory problems in major markets or loss of manufacturing competitiveness.
# - Overly optimistic assumptions baked into valuation (e.g., immediate mass-market FSD revenue).
#
# Practical next steps you can take right now
# - Check Tesla’s current price and valuation multiples (trailing/forward P/E, EV/Revenue).
# - Read the most recent earnings release and management commentary.
# - Decide on your target allocation and plan (one-time buy vs DCA).
# - If uncertain, consult a licensed financial advisor who can factor in your whole financial picture.
#
# Risk reminder
# This is general educational information, not personalized investment advice. Investing involves risk, including loss of principal. Past performance is no guarantee of future results, and no return is guaranteed. Consider consulting a licensed financial professional for advice tailored to your situation.
