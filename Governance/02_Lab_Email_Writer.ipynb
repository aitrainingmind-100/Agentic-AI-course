# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()
client = OpenAI()

SYSTEM = """
You are a professional email assistant.

GUARDRAILS:
- Maintain a polite and professional tone.
- No sarcasm.
- No emotional exaggeration.
- Keep it clear and structured.
- Use short paragraphs.
"""

def main():
    topic = input("Describe the email you want to write:\n")

    response = client.chat.completions.create(
        model="gpt-5-mini",
        messages=[
            {"role": "system", "content": SYSTEM},
            {"role": "user", "content": topic}
        ]
    )

    print("\nGenerated Email:\n")
    print(response.choices[0].message.content)

if __name__ == "__main__":
    main()
# Out:
# Generated Email:
#
# Subject: Invitation: Sign up for the Agentic AI Course (starts [Start Date])
#
# Hello [Name / Team],
#
# I’m excited to invite you to enroll in our Agentic AI course, starting on [Start Date]. This practical program covers building and deploying agentic systems — AI that plans, takes actions, and coordinates tasks — with hands-on labs and real-world case studies.
#
# Key details
# - Who it’s for: engineers, product managers, researchers, and anyone working with autonomous AI systems.
# - Format: [Live online / on-demand / hybrid] sessions + project work.
# - Duration & time commitment: [X weeks], ~[Y hours/week].
# - Outcomes: practical experience, project portfolio, and a certificate of completion.
# - Prerequisites: familiarity with Python and basic machine learning concepts (or completed [Prerequisite Course]).
#
# Why sign up
# - Learn to design safe, reliable agentic agents.
# - Apply best practices for evaluation, monitoring, and scaling.
# - Build a concrete project you can show stakeholders.
#
# How to register
# Please sign up here: [Registration Link]
# Registration closes on [Registration Deadline]. Seats are limited, so I encourage you to register early.
#
# If you’d like more details or have questions about fit or prerequisites, reply to this email or contact [Contact Name] at [Contact Email / Phone].
#
# Best regards,
# [Your Name]
# [Your Title]
# [Organization]
