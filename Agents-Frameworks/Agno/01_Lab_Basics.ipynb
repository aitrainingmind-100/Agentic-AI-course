# %%
# 01_agno_basic.py
from dotenv import load_dotenv
load_dotenv()

from agno.agent import Agent
from agno.models.openai import OpenAIChat

def main():
    agent = Agent(
        name="BasicAgent",
        model=OpenAIChat(id="gpt-4o-mini"),
        markdown=True,
        debug_mode=True
    )

    while True:
        q = input("\nAsk> ").strip()
        if not q or q.lower() in {"exit", "quit"}:
            break
        # run() returns a RunOutput; print_response() prints nicely in terminal
        agent.print_response(q, markdown=True)

if __name__ == "__main__":
    main()
# Out:
# DEBUG ******************* Agent ID: basicagent *******************
# DEBUG Creating new AgentSession: 8f24490f-891d-40f6-beb5-a94b0eedfd0f
# DEBUG ** Agent Run Start: d7867e29-afab-4bbf-826b-b29594426d8c ***
# DEBUG ------------------ OpenAI Response Start -------------------
# DEBUG -------------------- Model: gpt-4o-mini --------------------
# DEBUG ========================== system ==========================
# DEBUG <additional_information>
#       - Use markdown to format your answers.
#       </additional_information>
# DEBUG =========================== user ===========================
# DEBUG weather at mn
# DEBUG Creating new sync OpenAI client for model gpt-4o-mini
# Output()
# DEBUG ======================== assistant =========================
# DEBUG To provide the current weather for Minnesota (MN), I would need to reference a live source, which I can't do.
#       However, you can easily find up-to-date weather information for Minnesota by checking reliable weather
#       websites like:
#
#       - [Weather.com](https://weather.com)
#       - [AccuWeather](https://www.accuweather.com)
#       - Your local news station's weather page
#
#       These resources typically provide current temperature, precipitation forecasts, and other weather-related
#       data.
#
#       If you have a specific location in Minnesota, feel free to mention it, and I can help with general climate
#       information for that area!
# DEBUG ************************  METRICS  *************************
# DEBUG * Tokens:                      input=30, output=120, total=150
# DEBUG * Duration:                    2.8873s
# DEBUG * Tokens per second:           41.5619 tokens/s
# DEBUG ************************  METRICS  *************************
# DEBUG ------------------- OpenAI Response End --------------------
# DEBUG Added RunOutput to Agent Session
# DEBUG *** Agent Run End: d7867e29-afab-4bbf-826b-b29594426d8c ****
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
