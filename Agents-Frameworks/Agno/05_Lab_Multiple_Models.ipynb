# %%
# 05_agno_two_models_router_visible.py
from dotenv import load_dotenv
load_dotenv()

from agno.agent import Agent
from agno.models.openai import OpenAIChat
from agno.tools.duckduckgo import DuckDuckGoTools


# -------- Router Logic --------
def route(query: str) -> str:
    """
    Simple routing rules:
    - If it looks like research or long query → smart
    - Otherwise → fast
    """
    q = query.lower()

    if any(k in q for k in ["search", "latest", "news", "compare", "research", "sources"]):
        return "smart"

    if len(query) > 120:
        return "smart"

    return "fast"


def main():
    fast_agent = Agent(
        name="FastAgent",
        role="Handles simple questions quickly.",
        model=OpenAIChat(id="gpt-4o-mini"),
        debug_mode=True,
        markdown=True,
    )

    smart_agent = Agent(
        name="SmartAgent",
        role="Handles complex questions.",
        model=OpenAIChat(id="gpt-4o"),
        tools=[DuckDuckGoTools()],
              debug_mode=True,
        markdown=True,
    )

    print("Type exit to quit.")

    while True:
        q = input("\nAsk> ").strip()
        if not q or q.lower() in {"exit", "quit"}:
            break

        selected = route(q)

        print(f"\n[ROUTER] → {selected.upper()} agent selected")

        if selected == "smart":
            out = smart_agent.run(q)
        else:
            out = fast_agent.run(q)

        print("\nFinal Answer:\n", out)


if __name__ == "__main__":
    main()
# Out:
# DEBUG Function: web_search registered with websearch
# DEBUG Function: search_news registered with websearch
# Type exit to quit.
#
# [ROUTER] → FAST agent selected
# DEBUG ***** Session ID: 056bde90-ce30-4161-a3b2-791bc89440d0 *****
# Final Answer:
#  RunOutput(run_id='05fdb996-2a66-408d-80c7-d0b94b5f91d0', agent_id='fastagent', agent_name='FastAgent', session_id='056bde90-ce30-4161-a3b2-791bc89440d0', parent_run_id=None, workflow_id=None, user_id=None, input=RunInput(input_content='2+2', images=None, videos=None, audios=None, files=None), content='2 + 2 equals **4**.', content_type='str', reasoning_content=None, reasoning_steps=None, reasoning_messages=None, model_provider_data={'id': 'chatcmpl-DCbLIjRvgB5v3sykigZo7njMKsIZQ', 'system_fingerprint': 'fp_373a14eb6f'}, model='gpt-4o-mini', model_provider='OpenAI', messages=[Message(id='7ab46beb-5ebc-41d4-bb09-84db7f7dcf61', role='system', content='<your_role>\nHandles simple questions quickly.\n</your_role>\n\n<additional_information>\n- Use markdown to format your answers.\n</additional_information>', compressed_content=None, name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, files=None, audio_output=None, image_output=None, video_output=None, file_output=None, redacted_reasoning_content=None, provider_data=None, citations=None, reasoning_content=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, add_to_agent_memory=True, from_history=False, metrics=Metrics(input_tokens=0, output_tokens=0, total_tokens=0, cost=None, audio_input_tokens=0, audio_output_tokens=0, audio_total_tokens=0, cache_read_tokens=0, cache_write_tokens=0, reasoning_tokens=0, timer=None, time_to_first_token=None, duration=None, provider_metrics=None, additional_metrics=None), references=None, created_at=1771895852, temporary=False), Message(id='b5436f76-0ce1-433d-a0a9-d03f2c9be9aa', role='user', content='2+2', compressed_content=None, name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, files=None, audio_output=None, image_output=None, video_output=None, file_output=None, redacted_reasoning_content=None, provider_data=None, citations=None, reasoning_content=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, add_to_agent_memory=True, from_history=False, metrics=Metrics(input_tokens=0, output_tokens=0, total_tokens=0, cost=None, audio_input_tokens=0, audio_output_tokens=0, audio_total_tokens=0, cache_read_tokens=0, cache_write_tokens=0, reasoning_tokens=0, timer=None, time_to_first_token=None, duration=None, provider_metrics=None, additional_metrics=None), references=None, created_at=1771895852, temporary=False), Message(id='f62500d0-8d48-435e-9d1f-a851449d6e50', role='assistant', content='2 + 2 equals **4**.', compressed_content=None, name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, files=None, audio_output=None, image_output=None, video_output=None, file_output=None, redacted_reasoning_content=None, provider_data={'id': 'chatcmpl-DCbLIjRvgB5v3sykigZo7njMKsIZQ', 'system_fingerprint': 'fp_373a14eb6f'}, citations=None, reasoning_content=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, add_to_agent_memory=True, from_history=False, metrics=Metrics(input_tokens=43, output_tokens=9, total_tokens=52, cost=None, audio_input_tokens=0, audio_output_tokens=0, audio_total_tokens=0, cache_read_tokens=0, cache_write_tokens=0, reasoning_tokens=0, timer=None, time_to_first_token=None, duration=None, provider_metrics=None, additional_metrics=None), references=None, created_at=1771895852, temporary=False)], metrics=Metrics(input_tokens=43, output_tokens=9, total_tokens=52, cost=None, audio_input_tokens=0, audio_output_tokens=0, audio_total_tokens=0, cache_read_tokens=0, cache_write_tokens=0, reasoning_tokens=0, timer=<agno.utils.timer.Timer object at 0x10fef7a70>, time_to_first_token=0.0015642090002074838, duration=0.7243744590086862, provider_metrics=None, additional_metrics=None), additional_input=None, tools=[], images=None, videos=None, audio=None, files=None, response_audio=None, citations=None, references=None, metadata=None, session_state={'current_session_i ...
#
# [ROUTER] → SMART agent selected
#
# Final Answer:
#  RunOutput(run_id='959b6ef4-c0b1-407b-a930-68a2a033feba', agent_id='smartagent', agent_name='SmartAgent', session_id='b5b46aaf-048d-4474-b9f7-4f1828026fd6', parent_run_id=None, workflow_id=None, user_id=None, input=RunInput(input_content='Can uou tell me what is 2+2 and also tell me why it does addition instead of multiplications. Can we do algebra but what is algebra even mean ?', images=None, videos=None, audios=None, files=None), content="Certainly! Let's break down your questions into parts:\n\n### 1. What is \\(2 + 2\\)?\n\nThe arithmetic operation \\(2 + 2\\) equals 4. Addition is a fundamental arithmetic operation that combines two numbers to get their total.\n\n### 2. Why does it do addition instead of multiplication?\n\nAddition and multiplication are two different arithmetic operations with distinct purposes:\n\n- **Addition** is used to combine quantities. For example, \\(2 + 2\\) implies you have two items and add another two items to get a total of four items.\n  \n- **Multiplication** is like repeated addition. For instance, \\(2 \\times 2\\) means you take two items, and you have two such groups (or times you count them) to get a total of four items. \n\nIn your initial equation \\(2 + 2\\), we use addition because the problem explicitly defines a sum, not a product. Each operation type serves different computational needs.\n\n### 3. Can we do algebra? What does algebra mean?\n\n**Algebra** is indeed a branch of mathematics that deals with symbols and the rules for manipulating those symbols. These symbols represent numbers and relationships that help in expressing general mathematical laws and solving equations.\n\n- **Basic Algebra**: It involves finding the unknown values (often denoted as \\(x\\), \\(y\\), etc.) in equations. For example, solving \\(x + 3 = 7\\) helps in determining \\(x\\).\n\n- **Advanced Algebra**: It includes dealing with complex equations, functions, matrices, and more.\n\nAlgebra is widely used in various fields, such as science, engineering, medicine, and economics, for modeling and solving problems. \n\nIf you have any further questions or need more details on a specific topic, feel free to ask!", content_type='str', reasoning_content=None, reasoning_steps=None, reasoning_messages=None, model_provider_data={'id': 'chatcmpl-DCbLvyf4YCcG14kQdfxuLVAeOuTUD', 'system_fingerprint': 'fp_9e0d253e63'}, model='gpt-4o', model_provider='OpenAI', messages=[Message(id='47f02be8-ce33-4ce0-8d80-9f09411ac1e4', role='system', content='<your_role>\nHandles complex questions.\n</your_role>\n\n<additional_information>\n- Use markdown to format your answers.\n</additional_information>', compressed_content=None, name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, files=None, audio_output=None, image_output=None, video_output=None, file_output=None, redacted_reasoning_content=None, provider_data=None, citations=None, reasoning_content=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, add_to_agent_memory=True, from_history=False, metrics=Metrics(input_tokens=0, output_tokens=0, total_tokens=0, cost=None, audio_input_tokens=0, audio_output_tokens=0, audio_total_tokens=0, cache_read_tokens=0, cache_write_tokens=0, reasoning_tokens=0, timer=None, time_to_first_token=None, duration=None, provider_metrics=None, additional_metrics=None), references=None, created_at=1771895890, temporary=False), Message(id='1b5af409-19e4-435b-8b8f-3b3e48525e73', role='user', content='Can uou tell me what is 2+2 and also tell me why it does addition instead of multiplications. Can we do algebra but what is algebra even mean ?', compressed_content=None, name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, files=None, audio_output=None, image_output=None, video_output=None, file_output=None, redacted_reasoning_content=None, provider_data=None, citations=None, reasoning_content=None, tool_name=None, tool_args=None, tool_call_error=Non ...
