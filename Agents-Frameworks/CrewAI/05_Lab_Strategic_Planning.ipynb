# %%
ceo = Agent(role="CEO", goal="Drive growth strategy", llm=llm, verbose=True)
cto = Agent(role="CTO", goal="Evaluate technology feasibility", llm=llm, verbose=True)
cfo = Agent(role="CFO", goal="Analyze financial viability", llm=llm, verbose=True)
risk = Agent(role="Chief Risk Officer", goal="Identify compliance and risks", llm=llm, verbose=True)

crew = Crew(
    agents=[ceo, cto, cfo, risk],
    tasks=[
        Task(description="Should we invest $10M into building an AI platform?", agent=ceo),
        Task(description="Evaluate tech feasibility.", agent=cto),
        Task(description="Analyze financial impact.", agent=cfo),
        Task(description="Identify risks.", agent=risk),
    ],
    verbose=True
)

crew.kickoff()
